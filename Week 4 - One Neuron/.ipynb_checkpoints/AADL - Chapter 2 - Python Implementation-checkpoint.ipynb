# %% [markdown]
# # Neural Networks and Deep Learning for Life Sciences and Health Applications - An introductory course about theoretical fundamentals, case studies and implementations in python and tensorflow
#
# (C) Umberto Michelucci 2018 - umberto.michelucci@gmail.com
#
# github repository: https://github.com/michelucci/dlcourse2018_students
#
# Fall Semester 2018

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
import matplotlib as mpl

# %% [markdown]
# ## Function for plots

# %%
def myplot(x,y, name, xlab, ylab):
    plt.rc('font', family='arial')
    #plt.rc('font',**{'family':'serif','serif':['Palatino']}) 
    plt.rc('xtick', labelsize='x-small')
    plt.rc('ytick', labelsize='x-small')
    
    plt.tight_layout()

    fig = plt.figure(figsize=(8, 5))
    ax = fig.add_subplot(1, 1, 1)
    
    plt.tick_params(labelsize=16)


    #x = np.linspace(1., 8., 30)
    ax.plot(x, y, ls='solid', color = 'black')
    #ax.plot(x, 20/x, color='0.50', ls='dashed')
    ax.set_xlabel(xlab, fontsize = 16)
    ax.set_ylabel(ylab, fontsize = 16)

    fig.savefig(name+'.pdf', format='pdf', dpi=300,bbox_inches='tight')
    fig.savefig(name+'.png', format='png', dpi=300,bbox_inches='tight')

# %% [markdown]
# ## Activation functions plots

# %% [markdown]
# ### Creation of arrays of activation functions

# %%
x = np.arange(-5,5,0.1)
identity = x
sigmoid = 1.0 / (1.0 + np.exp(-x))
arctan = np.tanh(x)
relu = np.maximum(x, 0)
leakyrelu = relu - 0.05 * np.maximum(-x, 0)

# %% [markdown]
# ## Identity

# %%
myplot(x, identity, 'Figure_1-4', 'z', 'Identity $I(z)$')

# %% [markdown]
# ## Sigmoid activation function

# %%
myplot(x, sigmoid, 'Figure_1-5', 'z', 'sigmoid $\sigma(z)$')

# %% [markdown]
# ## tanh activation function

# %%
myplot(x, arctan, 'Figure_1-6', 'z', r'Hyperbolic Tangent $\tanh(z)$')

# %% [markdown]
# ## ReLU activation function

# %%
myplot(x, relu, 'Figure_1-7', 'z', 'ReLU')

# %% [markdown]
# ## Leaky ReLU Activation function

# %%
myplot(x, leakyrelu, 'Figure_1-8', 'z', 'Leaky ReLU')

# %% [markdown]
# # SWISH activation function

# %%
swish1 = x / (1.0 + np.exp(-0.1*x))
swish2 = x / (1.0 + np.exp(-0.5*x))
swish3 = x / (1.0 + np.exp(-10.0*x))

plt.rc('font', family='arial')
    #plt.rc('font',**{'family':'serif','serif':['Palatino']}) 
plt.rc('xtick', labelsize='x-small')
plt.rc('ytick', labelsize='x-small')
    
plt.tight_layout()

fig = plt.figure(figsize=(8, 5))
ax = fig.add_subplot(1, 1, 1)
plt.tick_params(labelsize=16)
ax.plot(x, swish1, ls='solid', color = 'black', label=r'$\beta=0.1$')
ax.plot(x, swish2, ls='dashed', color = 'black', label=r'$\beta=0.5$')
ax.plot(x, swish3, ls='dotted', color = 'black', label=r'$\beta=10.0$')
ax.set_xlabel('z', fontsize = 16)
ax.set_ylabel('SWISH activation function', fontsize = 16)
#plt.xlim(0,8)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

fig.savefig('Figure_1-9'+'.pdf', format='pdf', dpi=300,bbox_inches='tight')
fig.savefig('Figure_1-9'+'.png', format='png', dpi=300,bbox_inches='tight')

# %% [markdown]
# # Gradient Descent Plots

# %% [markdown]
# # Image for well behaved converging

# %%
import numpy as np
import matplotlib.pyplot as plt

# The data to fit
m = 30
theta0_true = 2
theta1_true = 0.5
x = np.linspace(-1,1,m)
y = theta0_true + theta1_true * x

# The plot: LHS is the data, RHS will be the cost function.
fig, ax = plt.subplots(figsize=(8, 5))
#ax[0].scatter(x, y, marker='x', s=40, color='k')
#fig = plt.figure(figsize=(3.9, 3.1))

plt.rc('font', family='arial')
    #plt.rc('font',**{'family':'serif','serif':['Palatino']}) 
plt.rc('xtick', labelsize='x-small')
plt.rc('ytick', labelsize='x-small')

def cost_func(theta0, theta1):
    """The cost function, J(theta0, theta1) describing the goodness of fit."""
    theta0 = np.atleast_3d(np.asarray(theta0))
    theta1 = np.atleast_3d(np.asarray(theta1))
    return np.average((y-hypothesis(x, theta0, theta1))**2, axis=2)/2

def hypothesis(x, theta0, theta1):
    """Our "hypothesis function", a straight line."""
    return theta0 + theta1*x

# First construct a grid of (theta0, theta1) parameter pairs and their
# corresponding cost function values.
theta0_grid = np.linspace(-1,4,101)
theta1_grid = np.linspace(-5,5,101)
J_grid = cost_func(theta0_grid[:,np.newaxis,np.newaxis],
                   theta1_grid[np.newaxis,:,np.newaxis])

# A labeled contour plot for the RHS cost function
X, Y = np.meshgrid(theta0_grid, theta1_grid)
contours = ax.contour(X, Y, J_grid, 30, colors='k')
ax.clabel(contours)
# The target parameter values indicated on the cost function contour plot
ax.scatter([theta0_true]*2,[theta1_true]*2,s=[50,10], color=['k','w'])

# Take N steps with learning rate alpha down the steepest gradient,
# starting at (theta0, theta1) = (0, 0).
N = 8
alpha = 0.7
theta = [np.array((0,0))]
J = [cost_func(*theta[0])[0]]
for j in range(N-1):
    last_theta = theta[-1]
    this_theta = np.empty((2,))
    this_theta[0] = last_theta[0] - alpha / m * np.sum(
                                    (hypothesis(x, *last_theta) - y))
    this_theta[1] = last_theta[1] - alpha / m * np.sum(
                                    (hypothesis(x, *last_theta) - y) * x)
    theta.append(this_theta)
    J.append(cost_func(*this_theta))


# Annotate the cost function plot with coloured points indicating the
# parameters chosen and red arrows indicating the steps down the gradient.
# Also plot the fit function on the LHS data plot in a matching colour.
colors = ['b', 'g', 'm', 'c', 'orange']
#ax[0].plot(x, hypothesis(x, *theta[0]), color=colors[0], lw=2,
#           label=r'$\theta_0 = {:.3f}, \theta_1 = {:.3f}$'.format(*theta[0]))
for j in range(1,N):
    ax.annotate('', xy=theta[j], xytext=theta[j-1],
                   arrowprops={'arrowstyle': '->', 'color': 'r', 'lw': 1},
                   va='center', ha='center')
    #ax[0].plot(x, hypothesis(x, *theta[j]), color=colors[j], lw=2,
    #       label=r'$\theta_0 = {:.3f}, \theta_1 = {:.3f}$'.format(*theta[j]))
ax.scatter(*zip(*theta), cmap='gray', s=40, lw=0)

# Labels, titles and a legend.
ax.set_xlabel(r'$w_0$')
ax.set_ylabel(r'$w_1$')
ax.set_title('Cost function')
#ax[0].set_xlabel(r'$x$')
#ax[0].set_ylabel(r'$y$')
#ax[0].set_title('Data and fit')
#axbox = ax[0].get_position()
# Position the legend by hand so that it doesn't cover up any of the lines.
#ax[0].legend(loc=(axbox.x0+0.5*axbox.width, axbox.y0+0.1*axbox.height),
#             fontsize='small')

plt.show()

fig.savefig('Figure_1-10'+'.pdf', format='pdf', dpi=300,bbox_inches='tight')
fig.savefig('Figure_1-10'+'.png', format='png', dpi=300,bbox_inches='tight')

# %% [markdown]
# ## Figure 1-11

# %%
J1=J

# %%
import numpy as np
import matplotlib.pyplot as plt

# The data to fit
m = 30
theta0_true = 2
theta1_true = 0.5
x = np.linspace(-1,1,m)
y = theta0_true + theta1_true * x

# The plot: LHS is the data, RHS will be the cost function.
fig, ax = plt.subplots(figsize=(8, 5))
#ax[0].scatter(x, y, marker='x', s=40, color='k')
#fig = plt.figure(figsize=(3.9, 3.1))

plt.rc('font', family='arial')
    #plt.rc('font',**{'family':'serif','serif':['Palatino']}) 
plt.rc('xtick', labelsize='x-small')
plt.rc('ytick', labelsize='x-small')

def cost_func(theta0, theta1):
    """The cost function, J(theta0, theta1) describing the goodness of fit."""
    theta0 = np.atleast_3d(np.asarray(theta0))
    theta1 = np.atleast_3d(np.asarray(theta1))
    return np.average((y-hypothesis(x, theta0, theta1))**2, axis=2)/2

def hypothesis(x, theta0, theta1):
    """Our "hypothesis function", a straight line."""
    return theta0 + theta1*x

# First construct a grid of (theta0, theta1) parameter pairs and their
# corresponding cost function values.
theta0_grid = np.linspace(-1,4,101)
theta1_grid = np.linspace(-5,5,101)
J_grid = cost_func(theta0_grid[:,np.newaxis,np.newaxis],
                   theta1_grid[np.newaxis,:,np.newaxis])

# A labeled contour plot for the RHS cost function
X, Y = np.meshgrid(theta0_grid, theta1_grid)
contours = ax.contour(X, Y, J_grid, 30, colors='k')
ax.clabel(contours)
# The target parameter values indicated on the cost function contour plot
ax.scatter([theta0_true]*2,[theta1_true]*2,s=[50,10], color=['k','w'])

# Take N steps with learning rate alpha down the steepest gradient,
# starting at (theta0, theta1) = (0, 0).
N = 8
alpha = 2
theta = [np.array((0,0))]
J = [cost_func(*theta[0])[0]]
for j in range(N-1):
    last_theta = theta[-1]
    this_theta = np.empty((2,))
    this_theta[0] = last_theta[0] - alpha / m * np.sum(
                                    (hypothesis(x, *last_theta) - y))
    this_theta[1] = last_theta[1] - alpha / m * np.sum(
                                    (hypothesis(x, *last_theta) - y) * x)
    theta.append(this_theta)
    J.append(cost_func(*this_theta))


# Annotate the cost function plot with coloured points indicating the
# parameters chosen and red arrows indicating the steps down the gradient.
# Also plot the fit function on the LHS data plot in a matching colour.
colors = ['b', 'g', 'm', 'c', 'orange']
#ax[0].plot(x, hypothesis(x, *theta[0]), color=colors[0], lw=2,
#           label=r'$\theta_0 = {:.3f}, \theta_1 = {:.3f}$'.format(*theta[0]))
for j in range(1,N):
    ax.annotate('', xy=theta[j], xytext=theta[j-1],
                   arrowprops={'arrowstyle': '->', 'color': 'r', 'lw': 1},
                   va='center', ha='center')
    #ax[0].plot(x, hypothesis(x, *theta[j]), color=colors[j], lw=2,
    #       label=r'$\theta_0 = {:.3f}, \theta_1 = {:.3f}$'.format(*theta[j]))
ax.scatter(*zip(*theta), cmap='gray', s=40, lw=0)

# Labels, titles and a legend.
ax.set_xlabel(r'$w_0$')
ax.set_ylabel(r'$w_1$')
ax.set_title('Cost function')
#ax[0].set_xlabel(r'$x$')
#ax[0].set_ylabel(r'$y$')
#ax[0].set_title('Data and fit')
#axbox = ax[0].get_position()
# Position the legend by hand so that it doesn't cover up any of the lines.
#ax[0].legend(loc=(axbox.x0+0.5*axbox.width, axbox.y0+0.1*axbox.height),
#             fontsize='small')
import numpy as np
import matplotlib.pyplot as plt

fig.savefig('Figure_1-11'+'.pdf', format='pdf', dpi=300,bbox_inches='tight')
fig.savefig('Figure_1-11'+'.png', format='png', dpi=300,bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Figure 1-12

# %%
J2=J

# %% [markdown]
# ## Learning rate too small

# %%
import numpy as np
import matplotlib.pyplot as plt

# The data to fit
m = 300
theta0_true = 2
theta1_true = 0.5
x = np.linspace(-1,1,m)
y = theta0_true + theta1_true * x

# The plot: LHS is the data, RHS will be the cost function.
fig, ax = plt.subplots(figsize=(8, 5))
#ax[0].scatter(x, y, marker='x', s=40, color='k')
#fig = plt.figure(figsize=(3.9, 3.1))

plt.rc('font', family='arial')
    #plt.rc('font',**{'family':'serif','serif':['Palatino']}) 
plt.rc('xtick', labelsize='x-small')
plt.rc('ytick', labelsize='x-small')

def cost_func(theta0, theta1):
    """The cost function, J(theta0, theta1) describing the goodness of fit."""
    theta0 = np.atleast_3d(np.asarray(theta0))
    theta1 = np.atleast_3d(np.asarray(theta1))
    return np.average((y-hypothesis(x, theta0, theta1))**2, axis=2)/2

def hypothesis(x, theta0, theta1):
    """Our "hypothesis function", a straight line."""
    return theta0 + theta1*x

# First construct a grid of (theta0, theta1) parameter pairs and their
# corresponding cost function values.
theta0_grid = np.linspace(-1,4,101)
theta1_grid = np.linspace(-5,5,101)
J_grid = cost_func(theta0_grid[:,np.newaxis,np.newaxis],
                   theta1_grid[np.newaxis,:,np.newaxis])

# A labeled contour plot for the RHS cost function
X, Y = np.meshgrid(theta0_grid, theta1_grid)
contours = ax.contour(X, Y, J_grid, 30, colors='k')
ax.clabel(contours)
# The target parameter values indicated on the cost function contour plot
ax.scatter([theta0_true]*2,[theta1_true]*2,s=[50,10], color=['k','w'])

# Take N steps with learning rate alpha down the steepest gradient,
# starting at (theta0, theta1) = (0, 0).
N = 30
alpha = 0.05
theta = [np.array((0,0))]
J = [cost_func(*theta[0])[0]]
for j in range(N-1):
    last_theta = theta[-1]
    this_theta = np.empty((2,))
    this_theta[0] = last_theta[0] - alpha / m * np.sum(
                                    (hypothesis(x, *last_theta) - y))
    this_theta[1] = last_theta[1] - alpha / m * np.sum(
                                    (hypothesis(x, *last_theta) - y) * x)
    theta.append(this_theta)
    J.append(cost_func(*this_theta))


# Annotate the cost function plot with coloured points indicating the
# parameters chosen and red arrows indicating the steps down the gradient.
# Also plot the fit function on the LHS data plot in a matching colour.
colors = ['b', 'g', 'm', 'c', 'orange']
#ax[0].plot(x, hypothesis(x, *theta[0]), color=colors[0], lw=2,
#           label=r'$\theta_0 = {:.3f}, \theta_1 = {:.3f}$'.format(*theta[0]))
for j in range(1,N):
    ax.annotate('', xy=theta[j], xytext=theta[j-1],
                   arrowprops={'arrowstyle': '->', 'color': 'r', 'lw': 1},
                   va='center', ha='center')
    #ax[0].plot(x, hypothesis(x, *theta[j]), color=colors[j], lw=2,
    #       label=r'$\theta_0 = {:.3f}, \theta_1 = {:.3f}$'.format(*theta[j]))
ax.scatter(*zip(*theta), cmap='gray', s=40, lw=0)

# Labels, titles and a legend.
ax.set_xlabel(r'$w_0$')
ax.set_ylabel(r'$w_1$')
ax.set_title('Cost function')
#ax[0].set_xlabel(r'$x$')
#ax[0].set_ylabel(r'$y$')
#ax[0].set_title('Data and fit')
#axbox = ax[0].get_position()
# Position the legend by hand so that it doesn't cover up any of the lines.
#ax[0].legend(loc=(axbox.x0+0.5*axbox.width, axbox.y0+0.1*axbox.height),
#             fontsize='small')

plt.show()

fig.savefig('Figure_1-12'+'.pdf', format='pdf', dpi=300,bbox_inches='tight')
fig.savefig('Figure_1-12'+'.png', format='png', dpi=300,bbox_inches='tight')

# %% [markdown]
# ### Figure 1-13 - Cost function for different gammas

# %%
J3=J

# %%
 plt.rc('font', family='arial')
    #plt.rc('font',**{'family':'serif','serif':['Palatino']}) 
plt.rc('xtick', labelsize='x-small')
plt.rc('ytick', labelsize='x-small')
    
plt.tight_layout()

fig = plt.figure(figsize=(3.9, 3.1))
ax = fig.add_subplot(1, 1, 1)
   #x = np.linspace(1., 8., 30)
ax.plot(J1, ls='solid', color = 'black', label='$\gamma=0.8$')
ax.plot(J2, ls='dashed', color = 'black', label='$\gamma=2.0$')
ax.plot(J3, ls='dotted', color = 'black', label='$\gamma=0.05$')
ax.set_xlabel('Iterations')
ax.set_ylabel('Cost function $J$')
plt.xlim(0,8)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

fig.savefig('Figure_1-13'+'.pdf', format='pdf', dpi=300,bbox_inches='tight')
fig.savefig('Figure_1-13'+'.png', format='png', dpi=300,bbox_inches='tight')

# %% [markdown]
# ## Difference between lists and numpy arrays

# %%
lst1 = random.sample(range(1, 10**8), 10**7)
lst2 = random.sample(range(1, 10**8), 10**7)

# %% [markdown]
# random.sample takes a population and a sample size k and returns k random members of the population.

# %% [markdown]
# ## With zip

# %%
# %%time
out1 = [a*b for a,b in zip(lst1,lst2)]
# Out:
# CPU times: user 1.28 s, sys: 58 ms, total: 1.34 s
# Wall time: 1.36 s

# %% [markdown]
# ## with enumerate

# %%
# %%time
ab = [val * lst2[i] for i, val in enumerate(lst1)]
# Out:
# CPU times: user 1.92 s, sys: 75.5 ms, total: 2 s
# Wall time: 2.05 s

# %% [markdown]
# ## Standard loop

# %%
# %%timeit
ab = [lst1[i]*lst2[i] for i in range(len(lst1))]
# Out:
# 2.06 s ± 326 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ## with numpy

# %%
# %%timeit
list1_np = np.array(lst1)
list2_np = np.array(lst2)
out2 = np.multiply(list1_np, list2_np)
# Out:
# 1.53 s ± 78.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
out2 = np.multiply(list1_np, list2_np)
# Out:
# 20.8 ms ± 2.5 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%time
out2 = np.multiply(lst1, lst2)
# Out:
# CPU times: user 1.65 s, sys: 61.4 ms, total: 1.71 s
# Wall time: 1.75 s

# %% [markdown]
# # Activation functions

# %% [markdown]
# ## Timing of ReLU Functions

# %%
x = np.random.random(10**8)

# %%
x.shape
# Out:
# (100000000,)

# %%
x = np.random.random(10**6)
print("max method 1:")
# %timeit -n10 np.maximum(x, 0, x)

print("max method 2:")
# %timeit -n10 np.maximum(x, 0)

print("multiplication method:")
# %timeit -n10 x * (x > 0)

print("abs method:")
# %timeit -n10 (abs(x) + x) / 2
# Out:
# max method 1:
# 2.66 ms ± 500 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# max method 2:
# 6.35 ms ± 836 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# multiplication method:
# 4.37 ms ± 780 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# abs method:
# 8.33 ms ± 784 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
